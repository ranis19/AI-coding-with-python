# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

#2. Generate and organize data
sales_data = np.array([
    [120, 150, 100],
    [130, 160, 110],
    [125, 170, 105]
])
months = ['Jan', 'Feb', 'Mar']
products = ['product A', 'product B', 'product C']
df=pd.DataFrame(data=sales_data,index=months, columns=products)
print(df)

print()

#3. Display Basic Statistics using df.describe()
summary = df.describe()
print(summary)
#mean is the average of the values
#min is the smallest value
#count is the number of data

print()

#4. Visualization and add markdown explanation of the chart
plt.plot(df.index, df['product A'], marker='o', label='Product A')
plt.plot(df.index, df['product B'], marker='x',label='Product B')
plt.plot(df.index, df['product C'], marker='^',label='Product C')
plt.title('Monthly Sales Performance')
plt.xlabel('Month')
plt.ylabel('Sales Units')
plt.legend() 
#product B shows consistant growth.

#% Download the notebook as clara_sales_task.ipynb

#Github instructions
#4. Contributor Tasks:
#Add a new function to calculate the median using NumPy
Product_A=sales_data[:3,0:1]
print('Median of Product_A:',np.median(Product_A))
Product_B=sales_data[:3,1:2]
print('Median of Product_B:',np.median(Product_B))
Product_C=sales_data[:3,2:]
print('Median of Product_C:',np.median(Product_C))

print()

#Add a new visualisation (eg., bar chart or histogram) using Matplotlib
# Out:
#      product A  product B  product C
# Jan        120        150        100
# Feb        130        160        110
# Mar        125        170        105
#
#        product A  product B  product C
# count        3.0        3.0        3.0
# mean       125.0      160.0      105.0
# std          5.0       10.0        5.0
# min        120.0      150.0      100.0
# 25%        122.5      155.0      102.5
# 50%        125.0      160.0      105.0
# 75%        127.5      165.0      107.5
# max        130.0      170.0      110.0
#
# Median of Product_A: 125.0
# Median of Product_B: 160.0
# Median of Product_C: 105.0

# %%
notebooks/clara_sales_task_Niran_commit.ipynb
