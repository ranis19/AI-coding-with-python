# %%
class Car:
    def __init__(self,brand,colour):
        self.brand = brand
        self.colour = colour
    def drive(self):
        print(f"The {self.colour} {self.brand} is now driving")
car1 = Car("Kia","Red")
car2 = Car("BMW","White")
car1.drive()
car2.drive()
# Out:
# The Red Kia is now driving
# The White BMW is now driving

# %%
class Car:
    def __init__(self,brand,colour):
        self.brand = brand
        self.colour = colour
    def drive(self):
        print(f"The {self.colour} {self.brand} is now driving")
car1 = Car("Kia","Red")
#car1 = Car("Kia","Blue")
car2 = Car("BMW","White")
car1.drive()
car2.drive()
# Out:
# The Red Kia is now driving
# The White BMW is now driving

# %%
class Animal:
    def __init__(self,name,species):
        self.name=name
        self.__species=species #private attribute
    def intro(self):
        print("This is",self.name,"and it is a",self.__species) 
pet1=Animal("Summer","Cat")
pet2=Animal("Winter","Cat")
#print(pet2.__species)  Private Attribute can be called outside of the class 
pet1.intro()
pet2.intro()
class Dog(Animal):
    def sound(self):
        print(self.name,"barks")
d=Dog("Buddy","dog")
d.sound()
# Out:
# This is Summer and it is a Cat
# This is Winter and it is a Cat
# Buddy barks

# %%
class Car:
    def __init__(self,brand,model):
        self.brnad = brand
        self.model = model
    def move(self):       #Polymorphism
        print("Drive!")
class Boat:
    def __init__(self,brand,model):
        self.brnad = brand
        self.model = model
    def move(self):
        print("Sail")#Polymorphism
class Plane:
    def __init__(self,brand,model):
        self.brnad = brand
        self.model = model
    def move(self):
        print("Fly!")#Polymorphism

car1 = Car("Ford", "Mustang")       
boat1 = Boat("Ibiza", "Touring 20") 
plane1 = Plane("Boeing", "747") 

for x in (car1,boat1,plane1):
    x.move()
# Out:
# Drive!
# Sail
# Fly!

# %%
class Shape():
    
    def __init__(self):
        self.shape = 'shape'
        
    def __str__(self):
        return "I am a {}.".format(self.shape)
s = Shape()
print(s)
class Polygon(Shape):
    
    def __init__(self):
        self.shape = 'polygon'
        self.side_lengths = None
        
    def compute_perimeter(self):
        print(sum(self.side_lengths))
    
    def get_number_of_edges(self):
        print(len(self.side_lengths))
p = Polygon()
print(p)
class Rectangle(Polygon):    
    def __init__(self):
        self.shape = 'rectangle'
        self.side_lengths = [1, 1, 1, 1]
rect = Rectangle()
rect.compute_perimeter()
class Triangle(Polygon):    
    def __init__(self):
        self.shape = 'triangle'
        self.side_lengths = [2, 2, 2] 
t = Triangle()
t.compute_perimeter()
t.get_number_of_edges()
print(t)
# Out:
# I am a shape.
# I am a polygon.
# 4
# 6
# 3
# I am a triangle.

# %%
import numpy as np
arr=np.array([[1],[2],[3],[4],[5]])
print(arr)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
array3 = np.array([[[
