# %%
class Animal:
    def __init__(self,name):
        self.name=name
    def speak(self):
        return "Some Sound"
class Dog(Animal):
    pass
myDog = Dog("Winter")
print(myDog.name)
# Out:
# Winter

# %%
class Vehicle:
    def __init__(self,brand):
        self.brand=brand
    def start(self):
        return self.brand+"starting"
class Car(Vehicle):
    pass
myCar=Car("BMW")
#myCar.brand
print(myCar.start())
# Out:
# 'BMWstarting'

# %%
class Employee:
    def __init__(self,name):
        self.name = name
class Manager(Employee):
    def __init__(self,name,department):
        super().__init__(name)
        self.department=department

myEmployee=Manager("David","Perfume")
myEmployee.name
# Out:
# 'David'

# %%
class Bass:
    def greet(self):
        return "Hello"
class Derived(Bass):
    def greet(self):
        parentGreet=super().greet()
        return parentGreet+" from Derived"

derived =Derived()
derived.greet()
# Out:
# 'Hello from Derived'

# %%
class Product:
    def __init__(self,name,price):
        self.name=name
        self.price=price
class Book(Product):
    def __init__(self,name,price,author):
        super().__init__(name,price)
        self.author = author
bk=Book("Python Guide",30000,"Kim")
bk.name,bk.price,bk.author
# Out:
# ('Python Guide', 30000, 'Kim')
