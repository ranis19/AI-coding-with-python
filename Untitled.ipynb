# %%
import math
print(math.sqrt(16)) #Use the module prefix

# %%
from math import sqrt 
print(sqrt(16)) 
#Import the specific function if you don't want to type math.
#every time, you can pull that specific tool out of the box and put it directly into your workspace

# %%
import math as m
print(m.sqrt(24))
#rename the module

# %%
import math
print(dir(math))
# it shows you every constant (like $pi$ or $e$) and every function (like sqrt, sin, or log) that the math module provides.
help(math.log2) # If you want to know what 'log2' does:

# %%
help(math.ceil)

# %%
#Goal: Calculate the area of a circle.
#Input: A radius $r = 7$.Requirement: Use the math.pi constant.Formula: $Area = \pi r^2$

import math
r=int(input("Enter a radius"))
print(math.pi*math.pow(r,2))

# %%
help(math.pow)

# %%
#Quiz 2: The Integer Architect 🏗️Goal: In programming, we often need to round numbers in specific directions. 
#    Use two different functions from dir(math) to handle the number $9.7$.
#    Round it up to the nearest integer (should result in $10$).
#    Round it down to the nearest integer (should result in $9$).
a=9.7
print("$",math.ceil(a))
print("$",math.floor(a))

# %%
#Quiz 3: The Right Triangle (Hypotenuse) 
#Goal: Find the distance between two points, or the longest side of a right triangle.
#Input: Side $a = 3$, Side $b = 4$.Requirement: Look through your dir(math) list for a function that calculates the hypotenuse directly
#(it's much faster than doing $a^2 + b^2$ manually!).Formula: $c = \sqrt{a^2 + b^2}$
a=3
b=4
c=math.sqrt(math.pow(a,2)+math.pow(b,2))
print(c)
print(math.hypot(a,b)) 
#hypot is a specialized function used to calculate the longest side of a right-angled triangle with other 2 sides.

# %%
import math
while True: 
    your_shape=input("Choose the shape : Circle, Rectangle, Triangle",)
    if your_shape.capitalize() in ["Circle", "Rectangle", "Triangle"]: 
        break
    print("That shape is not in our list. Try agian")
if your_shape.capitalize() == "Circle":
    r=float(input("Radius?:"))
    print("The area of circle is",round(math.pow(r,2)*math.pi,1))
if your_shape.capitalize() == "Rectangle":
    w=float(input("Width?"))
    l=float(input("lenght?"))
    print("The area of ractangle is",round(w*l,1))
if your_shape.capitalize() == "Triangle":
    b=float(input("Base?"))
    h=float(input("Height?"))
    print("The area of triangle is",round(b*h/2,1))
# Out:
# Choose the shape : Circle, Rectangle, Triangle circle

# %%
#Create a program that asks for two numbers and divides them.
#Handle:
#- ValueError
#- ZeroDivisionError
#- Any unexpected error
try:
    y_n1,y_n2 = map(float,input("Input two numbers.:").split())
    print(y_n1/y_n2)
except ZeroDivisionError:
    print("You can't divide by zero!")
except ValueError:
    print("That's not a valid number.")
except Exception as e:
    print("An unexpected error occurred:",e)
# Out:
# Input two numbers.: 5 10
# 0.5
