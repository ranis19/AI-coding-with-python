# %%
#Q1:Histogram of Exam Scores
#Plot a histogram of the eam_score column to visualize the distribution of scores.
#Hint:Use plt.his()and label the axes

import pandas as pd
try:
    df = pd.read_csv('studentsdata.csv', encoding='utf-8-sig')
    print(df)
except FileNotFoundError:
    print("no file found")
# Out:
#    Student ID         Name  Age Gender   Grade  GPA             Major
# 0         101   Alice Wong   20      F   Soph.  3.6  Computer Science
# 1         102    Ben Smith   21      M  Junior  3.2         Economics
# 2         103   Carla Diaz   19      F  Fresh.  3.8           Biology
# 3         104    David Lee   22      M  Senior  2.9           History
# 4         105   Emma Patel   20      F   Soph.  3.7       Mathematics
# 5         106  Frank Jones   23      M  Senior  3.1       Engineering
# 6         107    Grace Kim   21      F  Junior  3.9         Sociology
