# %%
class Animal:
    def __init__(self,name,species):
        self.name = name
        self.species = species
    def intro():
        print("Name of the dog is",self.name)
        print("Species of the dog is",self.species)

my_animal=Animal("Ti","Bulldog")
#my_animal2=Animal()
my_animal.intro()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e766bbf0399f> in <module>
#       9 my_animal=Animal("Ti","Bulldog")
#      10 #my_animal2=Animal()
# ---> 11 my_animal.intro()
#
# TypeError: intro() takes 0 positional arguments but 1 was given
