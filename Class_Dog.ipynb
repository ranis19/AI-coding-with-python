# %%
class Dog:
    def __init__(self,name,age): #attributes
        self.name=name
        self.age=age
    def bark(self): #method
        #print("Woof!LaLa")
        return "woof!"

        
my_dog = Dog("Buddy",3) #object
print(f"My dog's name is {my_dog.name} and age is {my_dog.age}. \nHe loves to {my_dog.bark()}")
# Out:
# My dog's name is Buddy and age is 3.
# He loves to woof!
